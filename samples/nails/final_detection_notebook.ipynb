# %%
import warnings
warnings.filterwarnings("ignore")

# %%
import os
import sys
import random
import math
import re
import time
import numpy as np
import tensorflow as tf
import matplotlib
import matplotlib.pyplot as plt
import matplotlib.patches as patches

# %%
ROOT_DIR = os.path.abspath("../../")
ROOT_DIR
# Out:
# 'C:\\Users\\hp\\Desktop\\push'

# %%
# Import Mask RCNN
sys.path.append(ROOT_DIR)  # To find local version of the library
from mrcnn import utils
from mrcnn import visualize
from mrcnn.visualize import display_images
import mrcnn.model as modellib
from mrcnn.model import log

from samples.nails import nails

# %matplotlib inline
# Out:
# Using TensorFlow backend.

# %%
# Path to Nails trained weights

#NAILS_WEIGHTS_PATH = "mask_rcnn_nails_0005.h5"  # TODO: update this path

# %%
config = nails.NailsConfig()
NAILS_DIR = os.path.join(ROOT_DIR, "samples\nails\imagedataset")

# %%
NAILS_DIR = 'C:\\Users\\hp\\Desktop\\push\\samples\\nails\\imagedataset'

# %%
# Override the training configurations with a few
# changes for inferencing.
class InferenceConfig(config.__class__):
    # Run detection on one image at a time
    GPU_COUNT = 1
    IMAGES_PER_GPU = 1

config = InferenceConfig()
config.display()
# Out:
# Configurations:
# BACKBONE                       resnet101
# BACKBONE_STRIDES               [4, 8, 16, 32, 64]
# BATCH_SIZE                     1
# BBOX_STD_DEV                   [0.1 0.1 0.2 0.2]
# COMPUTE_BACKBONE_SHAPE         None
# DETECTION_MAX_INSTANCES        100
# DETECTION_MIN_CONFIDENCE       0.7
# DETECTION_NMS_THRESHOLD        0.3
# FPN_CLASSIF_FC_LAYERS_SIZE     1024
# GPU_COUNT                      1
# GRADIENT_CLIP_NORM             5.0
# IMAGES_PER_GPU                 1
# IMAGE_CHANNEL_COUNT            3
# IMAGE_MAX_DIM                  1024
# IMAGE_META_SIZE                14
# IMAGE_MIN_DIM                  800
# IMAGE_MIN_SCALE                0
# IMAGE_RESIZE_MODE              square
# IMAGE_SHAPE                    [1024 1024    3]
# LEARNING_MOMENTUM              0.9
# LEARNING_RATE                  0.001
# LOSS_WEIGHTS                   {'rpn_class_loss': 1.0, 'rpn_bbox_loss': 1.0, 'mrcnn_class_loss': 1.0, 'mrcnn_bbox_loss': 1.0, 'mrcnn_mask_loss': 1.0}
# MASK_POOL_SIZE                 14
# MASK_SHAPE                     [28, 28]
# MAX_GT_INSTANCES               100
# MEAN_PIXEL                     [123.7 116.8 103.9]
# MINI_MASK_SHAPE                (56, 56)
# NAME                           nails
# NUM_CLASSES                    2
# POOL_SIZE                      7
# POST_NMS_ROIS_INFERENCE        1000
# POST_NMS_ROIS_TRAINING         2000
# PRE_NMS_LIMIT                  6000
# ROI_POSITIVE_RATIO             0.33
# RPN_ANCHOR_RATIOS              [0.5, 1, 2]
# RPN_ANCHOR_SCALES              (32, 64, 128, 256, 512)
# RPN_ANCHOR_STRIDE              1
# RPN_BBOX_STD_DEV               [0.1 0.1 0.2 0.2]
# RPN_NMS_THRESHOLD              0.7
# RPN_TRAIN_ANCHORS_PER_IMAGE    256
# STEPS_PER_EPOCH                1000
# TOP_DOWN_PYRAMID_SIZE          256
# TRAIN_BN                       False
# TRAIN_ROIS_PER_IMAGE           200
# USE_MINI_MASK                  True
# USE_RPN_ROIS                   True
# VALIDATION_STEPS               50
# WEIGHT_DECAY                   0.0001

# %%
# Device to load the neural network on.
# Useful if you're training a model on the same 
# machine, in which case use CPU and leave the
# GPU for training.
DEVICE = "/cpu:0"  # /cpu:0 or /gpu:0

# Inspect the model in training or inference modes
# values: 'inference' or 'training'
# TODO: code for 'training' test mode not ready yet
TEST_MODE = "inference"

# %%
def get_ax(rows=1, cols=1, size=16):

    _, ax = plt.subplots(rows, cols, figsize=(size*cols, size*rows))
    return ax

# %%
# Load validation dataset
dataset = nails.NailsDataset()
dataset.load_nails(NAILS_DIR, "val")

# Must call before using the dataset
dataset.prepare()

print("Images: {}\nClasses: {}".format(len(dataset.image_ids), dataset.class_names))
# Out:
# Images: 3
# Classes: ['BG', 'nails']

# %%
MODEL_DIR = os.path.join(ROOT_DIR, "logs")

# %%
MODEL_DIR
# Out:
# 'C:\\Users\\hp\\Desktop\\push\\logs'

# %%
# Create model in inference mode
with tf.device(DEVICE):
    model = modellib.MaskRCNN(mode="inference", model_dir=MODEL_DIR,
                              config=config)
# Out:
# WARNING: Logging before flag parsing goes to stderr.
# W0925 06:52:04.488118 22524 deprecation_wrapper.py:119] From C:\ProgramData\Anaconda3\lib\site-packages\keras\backend\tensorflow_backend.py:517: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.
#
# W0925 06:52:04.614156 22524 deprecation_wrapper.py:119] From C:\ProgramData\Anaconda3\lib\site-packages\keras\backend\tensorflow_backend.py:74: The name tf.get_default_graph is deprecated. Please use tf.compat.v1.get_default_graph instead.
#
# W0925 06:52:04.855730 22524 deprecation_wrapper.py:119] From C:\ProgramData\Anaconda3\lib\site-packages\keras\backend\tensorflow_backend.py:4138: The name tf.random_uniform is deprecated. Please use tf.random.uniform instead.
#
# W0925 06:52:05.084883 22524 deprecation_wrapper.py:119] From C:\ProgramData\Anaconda3\lib\site-packages\keras\backend\tensorflow_backend.py:1919: The name tf.nn.fused_batch_norm is deprecated. Please use tf.compat.v1.nn.fused_batch_norm instead.
#
# W0925 06:52:05.121751 22524 deprecation_wrapper.py:119] From C:\ProgramData\Anaconda3\lib\site-packages\keras\backend\tensorflow_backend.py:3976: The name tf.nn.max_pool is deprecated. Please use tf.nn.max_pool2d instead.
#
# W0925 06:52:07.895335 22524 deprecation_wrapper.py:119] From C:\ProgramData\Anaconda3\lib\site-packages\keras\backend\tensorflow_backend.py:2018: The name tf.image.resize_nearest_neighbor is deprecated. Please use tf.compat.v1.image.resize_nearest_neighbor instead.
#
# W0925 06:52:08.653348 22524 deprecation_wrapper.py:119] From C:\ProgramData\Anaconda3\lib\site-packages\mask_rcnn-2.1-py3.7.egg\mrcnn\model.py:341: The name tf.log is deprecated. Please use tf.math.log instead.
#
# W0925 06:52:08.662324 22524 deprecation.py:323] From C:\ProgramData\Anaconda3\lib\site-packages\mask_rcnn-2.1-py3.7.egg\mrcnn\model.py:399: add_dispatch_support.<locals>.wrapper (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where
# W0925 06:52:08.670303 22524 deprecation.py:506] From C:\ProgramData\Anaconda3\lib\site-packages\mask_rcnn-2.1-py3.7.egg\mrcnn\model.py:423: calling crop_and_resize_v1 (from tensorflow.python.ops.image_ops_impl) with box_ind is deprecated and will be removed in a future version.
# Instructions for updating:
# box_ind is deprecated, use box_indices instead
# W0925 06:52:09.433610 22524 deprecation_wrapper.py:119] From C:\ProgramData\Anaconda3\lib\site-packages\mask_rcnn-2.1-py3.7.egg\mrcnn\model.py:720: The name tf.sets.set_intersection is deprecated. Please use tf.sets.intersection instead.
#
# W0925 06:52:09.472828 22524 deprecation_wrapper.py:119] From C:\ProgramData\Anaconda3\lib\site-packages\mask_rcnn-2.1-py3.7.egg\mrcnn\model.py:722: The name tf.sparse_tensor_to_dense is deprecated. Please use tf.sparse.to_dense instead.
#
# W0925 06:52:09.588831 22524 deprecation.py:323] From C:\ProgramData\Anaconda3\lib\site-packages\mask_rcnn-2.1-py3.7.egg\mrcnn\model.py:772: to_float (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.cast` instead.

# %%
weights_path = model.find_last()

# %%
weights_path
# Out:
# 'C:\\Users\\hp\\Desktop\\push\\logs\\nails20190910T2317\\mask_rcnn_nails_0015.h5'

# %%
print("Loading weights ", weights_path)
model.load_weights(weights_path, by_name=True)
# Out:
# Loading weights  C:\Users\hp\Desktop\push\logs\nails20190910T2317\mask_rcnn_nails_0015.h5
# Re-starting from epoch 15

# %%
# Load validation dataset
dataset = nails.NailsDataset()
dataset.load_nails(NAILS_DIR, "val")

# Must call before using the dataset
dataset.prepare()

print("Images: {}\nClasses: {}".format(len(dataset.image_ids), dataset.class_names))
# Out:
# Images: 3
# Classes: ['BG', 'nails']

# %%
dataset.image_ids
# Out:
# array([0, 1, 2])

# %%
image_id = 1
image, image_meta, gt_class_id, gt_bbox, gt_mask =\
    modellib.load_image_gt(dataset, config, image_id, use_mini_mask=False)
#info = dataset.image_info[image_id]
#print("image ID: {}.{} ({}) {}".format(info["source"], info["id"], image_id,dataset.image_reference(image_id)))

# Run object detection
results = model.detect([image], verbose=1)

# Display results
ax = get_ax(1)
r = results[0]
visualize.display_instances(image, r['rois'], r['masks'], r['class_ids'], 
                            dataset.class_names, r['scores'], ax=ax,
                            title="Predictions")
log("gt_class_id", gt_class_id)
log("gt_bbox", gt_bbox)
log("gt_mask", gt_mask)
# Out:
# Processing 1 images
# image                    shape: (1024, 1024, 3)       min:    0.00000  max:  250.00000  uint8
# molded_images            shape: (1, 1024, 1024, 3)    min: -123.70000  max:  133.10000  float64
# image_metas              shape: (1, 14)               min:    0.00000  max: 1024.00000  int32
# anchors                  shape: (1, 261888, 4)        min:   -0.35390  max:    1.29134  float32
# gt_class_id              shape: (4,)                  min:    1.00000  max:    1.00000  int32
# gt_bbox                  shape: (4, 4)                min:  324.00000  max:  883.00000  int32
# gt_mask                  shape: (1024, 1024, 4)       min:    0.00000  max:    1.00000  uint8

# %%
import skimage

# %%
image = skimage.io.imread('my.jpg')

# %%
skimage.io.imshow(image)

# %%
results = model.detect([image], verbose =1)

r = results[0]
visualize.display_instances(image, r['rois'], r['masks'], r['class_ids'], 
                            dataset.class_names, r['scores'], ax=ax,
                            title="Predictions")
# Out:
# Processing 1 images
# image                    shape: (2000, 1488, 3)       min:    0.00000  max:  255.00000  uint8
# molded_images            shape: (1, 1024, 1024, 3)    min: -123.70000  max:  151.10000  float64
# image_metas              shape: (1, 14)               min:    0.00000  max: 2000.00000  float64
# anchors                  shape: (1, 261888, 4)        min:   -0.35390  max:    1.29134  float32

# %%
# Display results
ax = get_ax(1)
r = results[0]
visualize.display_instances(image, r['rois'], r['masks'], r['class_ids'], 
                            dataset.class_names, r['scores'], ax=ax,
                            title="Predictions")
log("gt_class_id", gt_class_id)
log("gt_bbox", gt_bbox)
log("gt_mask", gt_mask)
# Out:
# gt_class_id              shape: (4,)                  min:    1.00000  max:    1.00000  int32
# gt_bbox                  shape: (4, 4)                min:  324.00000  max:  883.00000  int32
# gt_mask                  shape: (1024, 1024, 4)       min:    0.00000  max:    1.00000  uint8

# %% [markdown]
# ### Basic Application of Uniform Shade On Nails

# %%
def apply_shade(image,mask,shade):
    # Copy color pixels from the original color image where mask is set
    if mask.shape[-1] > 0:
        # We're treating all instances as one, so collapse the mask into one layer
        mask = (np.sum(mask, -1, keepdims=True) >= 1)
        splash = np.where(mask,shade,image).astype(np.uint8)
    return splash

# %%
shade = skimage.io.imread('global.jpg')

# %%
from skimage.transform import resize
shade = resize(shade, image.shape)

# %%
after_shade = apply_shade(image,r['masks'],shade)

# %%
skimage.io.imshow(after_shade)
